# %% [markdown]
# # **Variables in Machine Learning**
# ---
#
# <br/>

# %% [markdown]
# ### **Definition**
# ---
#
# - In Machine Learning, a variable is a characteristic or piece of information about an observation in a dataset.
#
# <br/>
#
# - **For example**, consider a house-price dataset:
#
# <img src="images/Variables ML/Variables-Example.png" width=700px/>
#
# - Here, Area, Bedrooms, Location, Age, and Price are variables.
#
# <br/>

# %% [markdown]
# ### **Independent Variable VS Dependent Variable**
# ---
#
# <br/>
#
# <img src="images/Variables ML/Independent_VS_Dependent_Variables.png" width=1000/>
#
# <br/>

# %% [markdown]
# ### **Types of Variable**
# ---
#
# <br/>
#
# <img src="images/Variables ML/Types_of_Variable.png" width=1000/>
#
# <br/>
