# %% [markdown]
# # **Importing Neccessary Libraries**

# %% [markdown]
# # **Probability Distribution**
# ---
#
# - Probability Distribution describe how the probabilities of different outcomes are distributed over the sample space of a random variable.
#
# <ul style="margin-left: 50px">
# <li>Discrete Probability Distribution</li>
# <li>Continuous Probability Distribution</li>
# </ul>

# %% [markdown]
# # **Probability Distribution Functions**
# ---
#
# <ul style="margin-left: 50px;">
# <li>Probability Density Function <b>(PDF)</b></li>
# <li>Probability Mass Function <b>(PMF)</b></li>
# <li>Cumulative Density Function <b>(CDF)</b></li>
# </ul>

# %% [markdown]
#  ## **Normal Distribution Function**
# ---
#
# #### **Normal Distribution:**
# - The Normal Distribution (also known as the Gaussian Distribution or "bell curve") is the most important continuous probability distribution in statistics and data science.
#
# <br/>
#
# #### **Formula**
# <img src="images/Probability_Distribution/Normal-Distribution-Formula.png" width=650>

# %% [markdown]
# ## **Standard Normal Distribution Function**
# ---
#
# #### **Standard Normal Distribution:**
# - A Standard Normal Distribution is a special case of the normal distribution where:
#
# <ul style="margin-left: 50px;">
# <li>Mean (μ) = 0</li>
# <li>Standard Deviation (σ) = 1</li>
# </ul>
#
# <br/>
#
# #### **Z-score Formula**
# <img src="images/Probability_Distribution/Standard-Normal-Distribution-Formula.png" width=650>
