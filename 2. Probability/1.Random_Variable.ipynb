# %% [markdown]
# # **Random Variable**
# ---
#
# - A Random Variable x is a function that assigns a real number to each outcome in the sample space of a random experiment.

# %% [markdown]
# # **Types of Random Variable**
# ---
#
# <br/>
#
# #### **Discrete Random Variable**
# - A random variable that takes on a countable number of distinct values.
# - **Example:** &emsp; _dice = {H,T}_ &emsp; **--->** &emsp; dice can only give Head **{H}** or Tail **{T}**.
#
# <br/>
# <img src="images/Random_Variable/Discrete-Random-Variable-Formula.png" width=550/>
#
# <br/>
#
# #### **Continous Random Variable**
# - A random variable that can take on any value within a given range or interval.
# - **Example:** &emsp; _age = [20, 40]_ &emsp; **--->** &emsp; age can be between **20** to **40** **(eg. can be 25)**
#
# <br/>
# <img src="images/Random_Variable/Continous-Random-Variable-Formula.png" width=550/>
