# %% [markdown]
# # **Covariance**
# ---
#
# ### **Covariance**
# - Covariance signifies the direction of the linear relationship between the two variables.
# - By direction we mean if the variables are directly proportional or inversely proportional to each other.
# - (Increasing the value of a one variable might have a positive or a negative impact on the value of the other variable)
#
# <br/>
#
# - **Range:** (-∞ to ∞)
#
# <br/>
#
# #### **Formula**
# <img src="images/Covariance/Covariance-Formula.png" width=600/>
