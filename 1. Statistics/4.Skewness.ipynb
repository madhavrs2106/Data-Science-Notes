# %% [markdown]
# # **Importing Neccessary Libraries**
# ---

# %%
# --- import Libraries to use their Functions
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- Changing working directory to current folder
file_directory = os.getcwd()
os.chdir(file_directory)

# %% [markdown]
# # **Skewness**
# ---
#
# - Skewness measures the asymmetry of the distribution.
# - A skewness value of 0 indicates a perfectly symmetrical distrbution.
# - **Positive skewness** indicates that the distribution is skewed to the right  (the tail is longer on the right).
# - **Negative skewness** indicates that the distribution is skewed to the left  (the tail is longer on the left).
#
# <br/>
#
# <img src="images/Skewness/Skewness-Formula.png" width=650/>

# %%
reader = pd.read_csv("Titanic-Dataset.csv", chunksize=1000)
titanic_df = pd.concat(reader, ignore_index=True)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### **Removing Null-Attributes**

# %%
titanic_df = titanic_df.dropna(subset=["Age","Fare"])


print(
    f" Null Attributes in Age:   {titanic_df["Age"].isnull().sum()}\n"
    f" Null Attributes in Fare:  {titanic_df["Fare"].isnull().sum()}"
)
# Out:
#  Null Attributes in Age:   0
#  Null Attributes in Fare:  0

# %% [markdown]
# ## **Positive Skewness**
# ---
#
# - **Positive skewness** is greater than **0**.
# - **Mean** of Positive skewness lies to the **Right of both mean & median**.
# - **Median** of Positive skewness is at **Middle of the data**.
# - **Mode** of Positive skewness is at **Peak on the graph**.
#
# <img src="images/Skewness/Positive-Skewness-Sequence.png" width=400/>

# %% [markdown]
# |#### **Dataset**

# %%
dataset_PS = pd.DataFrame({
    "Data" : [2,8,10,15,16,18,19,20,21,22,23,24,25,25,25,25,26,28,28,29,30,31,32,34,35,38,37,39,40,42,43,44,45,48,50,54,57,63,65,68,71,75,85,88,97]
})

dataset_PS.head()
# Out:
#    Data
# 0     2
# 1     8
# 2    10
# 3    15
# 4    16

# %% [markdown]
# #### **Positive Skewness**

# %%
mean_PS = dataset_PS["Data"].mean()
median_PS = dataset_PS["Data"].median()
mode_PS = dataset_PS["Data"].mode()[0]

print(
    f" Positive Skewness:  {dataset_PS["Data"].skew()}\n\n"
    f" -->  Mean Positive-Skewness:  {mean_PS}\n"
    f" -->  Median Positive-Skewness:  {median_PS}\n"
    f" -->  Mode Skewness:  {mode_PS}"
)
# Out:
#  Positive Skewness:  0.931943170420888
#
#  -->  Mean Positive-Skewness:  38.22222222222222
#  -->  Median Positive-Skewness:  32.0
#  -->  Mode Skewness:  25

# %% [markdown]
# #### **Positive Skewness Graph**

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE-line
sns.histplot(x="Data", data=dataset_PS, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Pont-lines
plt.axvline(mean_PS, color="red", linestyle="-", linewidth=2, label="Mean of Positive-Skewness")
plt.axvline(median_PS, color="green", linestyle="-", linewidth=2, label="Median of Positive-Skewness")
plt.axvline(mode_PS, color="blue", linestyle="-", linewidth=2, label="Mode of Positive-Skewness")

# --- Adding Title & Labels to the Graph
plt.title("Positive Skewness Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10)])
plt.yticks([i for i in range(0,16, 1)])

# --- Adding Grid-lines and Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend(loc="upper right")

# --- Shows Chart
plt.show()

# %% [markdown]
# ## **Negative Skewness**
# ---
#
# - **Negative Skewness** is lower than **0**.
# - **Mean** of Negative Skewness lies to the **Left of both mean & median**.
# - **Median** of Negative Skewness is at **Middle of the data**.
# - **Mode** of Negative Skewness is at **Peak of the graph**.
#
# <img src="images/Skewness/Negative-Skewness-Sequence.png" width=400/>

# %% [markdown]
# #### **Dataset**

# %%
dataset_NS = pd.DataFrame({
    "Data" : [2,13,18,24,26,33,36,38,42,44,48,52,54,55,56,58,59,61,62,65,66,66,67,68,69,71,72,72,73,74,75,75,75,75,76,77,78,79,81,84,85,86,88,97,98]
})

dataset_NS.head()
# Out:
#    Data
# 0     2
# 1    13
# 2    18
# 3    24
# 4    26

# %% [markdown]
# #### **Negative Skewness**

# %%
mean_NS = dataset_NS["Data"].mean()
median_NS = dataset_NS["Data"].median()
mode_NS = dataset_NS["Data"].mode()[0]

print(
    f" Negative Skewness:  {dataset_NS["Data"].skew()}\n\n"
    f" -->  Mean Negative Skewness:  {mean_NS}\n"
    f" -->  Median Negative Skewness:  {median_NS}\n"
    f" -->  Mode Skewness:  {mode_NS}"
)
# Out:
#  Negative Skewness:  -0.8608526366131748
#
#  -->  Mean Negative Skewness:  61.62222222222222
#  -->  Median Negative Skewness:  67.0
#  -->  Mode Skewness:  75

# %% [markdown]
# #### **Negative Skewness Graph**

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE line
sns.histplot(x="Data", data=dataset_NS, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Point-lines
plt.axvline(mean_NS, color="red", linestyle="-", linewidth=2, label="Mean of Negative-Skewness")
plt.axvline(median_NS, color="green", linestyle="-", linewidth=2, label="Median of Negative-Skewness")
plt.axvline(mode_NS, color="blue", linestyle="-", linewidth=2, label="Mode of Negative-Skewness")

# --- Adding Title & Labels
plt.title("Negative Skewness Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10,)])
plt.yticks([i for i in range(0,16, 1)])

# --- Adding Grid-lines & Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend(loc="upper left")

# --- Shows Chart
plt.show()

# %% [markdown]
# ## **Nornal Distribution (no-skewness)**
# ---
#
# - **Normal Distribution** or **No skewness** is equal to **0**.
# - **Mean**, **Median** & **Mode** of Normal Distribution lies at **Center of the data**.
#
# <img src="images/Skewness/Normal-Distribution-Sequence.png" width=400/>

# %% [markdown]
# #### **Dataset**

# %%
dataset_ND = pd.DataFrame({
    "Data": [4,15,18, 24,27,28,34, 35,36,38,39, 41,42,43,44,45,45,46,46,47,48,48,49, 50,50,50,50,51,52,53,54,55,56,57,57,58,59, 61,61,62,64,65, 72,74,75,76, 84,87, 98]
})

dataset_ND.head()
# Out:
#    Data
# 0     4
# 1    15
# 2    18
# 3    24
# 4    27

# %% [markdown]
# #### **Normal Distribution**

# %%
mean_ND = dataset_ND["Data"].mean()
median_ND = dataset_ND["Data"].median()
mode_ND = dataset_ND["Data"].mode()[0]

print(
    f" Normal Distribution:  {dataset_ND["Data"].skew()}\n\n"
    f" -->  Mean Normal Distribution:  {mean_ND}\n"
    f" -->  Median Normal Distribution:  {median_ND}\n"
    f" -->  Mode Normal Distribution:  {mode_ND}\n"
)
# Out:
#  Normal Distribution:  0.07453503380794854
#
#  -->  Mean Normal Distribution:  50.46938775510204
#  -->  Median Normal Distribution:  50.0
#  -->  Mode Normal Distribution:  50

# %% [markdown]
# #### **Normal Distribution Graph**

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE-line
sns.histplot(x="Data", data=dataset_ND, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Point-lines
plt.axvline(mean_ND, color="red", linestyle="-", linewidth=2, label="Mean of Normal-Distribution")
plt.axvline(median_ND, color="green", linestyle="-", linewidth=2, label="Median of Normal-Distribution")
plt.axvline(median_ND, color="blue", linestyle="-", linewidth=2, label="Median of Normal-Distribution")

# --- Adding Title & Labels
plt.title("Normal Distribution Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10)])
plt.yticks([i for i in range(0,16, 1)])

# --- Adding Grid-lines & Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend()

# --- Shows Chart
plt.show()

# %% [markdown]
# ## **Some Other Distribution Charts**
# ---

# %% [markdown]
# - #### **Uniform Distribution**

# %%
dataset_UD = pd.DataFrame({
    "Data": [1,8,9,13,16,18, 24,27,28,34,36,38,43,45,48,52,55,57,62,64,65,72,74,76,84,86,89,91,94,99]
})
mean_UD = dataset_UD["Data"].mean()
median_UD = dataset_UD["Data"].median()
mode_UD = dataset_UD["Data"].mode()[0]

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE-line
sns.histplot(x="Data", data=dataset_UD, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Point-lines
plt.axvline(mean_UD, color="red", linestyle="-", linewidth=2, label="Mean of Normal-Distribution")
plt.axvline(median_UD, color="green", linestyle="-", linewidth=2, label="Median of Normal-Distribution")
plt.axvline(median_UD, color="blue", linestyle="-", linewidth=2, label="Median of Normal-Distribution")

# --- Adding Title & Labels
plt.title("Uniform Distribution Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10)])
plt.yticks([i for i in range(0,6, 1)])

# --- Adding Grid-lines & Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend()

# --- Shows Chart
plt.show()

# %% [markdown]
# - #### **Symmetric Bimodal Distribution**

# %%
dataset_SBD = pd.DataFrame({
    "Data": [1,15,18,24,27,28,29,36,38,48,55,64,65,72,74,76,78,84,89,99]
})
mean_SBD = dataset_UD["Data"].mean()
median_SBD = dataset_UD["Data"].median()
mode_SBD = dataset_UD["Data"].mode()[0]

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE-line
sns.histplot(x="Data", data=dataset_SBD, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Point-lines
plt.axvline(mean_SBD, color="red", linestyle="-", linewidth=2, label="Mean of Normal-Distribution")
plt.axvline(median_SBD, color="green", linestyle="-", linewidth=2, label="Median of Normal-Distribution")
plt.axvline(median_SBD, color="blue", linestyle="-", linewidth=2, label="Median of Normal-Distribution")

# --- Adding Title & Labels
plt.title("Symmetric Bimodal Distribution Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10)])
plt.yticks([i for i in range(0,6, 1)])

# --- Adding Grid-lines & Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend()

# --- Shows Chart
plt.show()

# %% [markdown]
# - #### **Non-Symmetric Bimodal Distribution**

# %%
dataset_NSBD = pd.DataFrame({
    "Data": [1,15,17,18,24,27,28,29,36,38,48,55,64,65,72,76,78,84,89,99]
})
mean_NSBD = dataset_UD["Data"].mean()
median_NSBD = dataset_UD["Data"].median()
mode_NSBD = dataset_UD["Data"].mode()[0]

# %%
# --- Setting Figure size of Chart
plt.figure(figsize = (12,6))

# --- Creating Histogram & KDE-line
sns.histplot(x="Data", data=dataset_NSBD, kde=True, bins=[i for i in range(0,101, 10)])

# --- Adding Mean, Median & Mode Point-lines
plt.axvline(mean_NSBD, color="red", linestyle="-", linewidth=2, label="Mean of Normal-Distribution")
plt.axvline(median_NSBD, color="green", linestyle="-", linewidth=2, label="Median of Normal-Distribution")
plt.axvline(median_NSBD, color="blue", linestyle="-", linewidth=2, label="Median of Normal-Distribution")

# --- Adding Title & Labels
plt.title("Non-Symmetric Bimodal Distribution Graph", fontsize=20, fontweight="bold")
plt.xlabel("Values", fontsize=14, fontweight="bold")
plt.ylabel("Frequency", fontsize=14, fontweight="bold")

# --- Adding X & Y axis values (manually)
plt.xticks([i for i in range(0,101, 10)])
plt.yticks([i for i in range(0,6, 1)])

# --- Adding Grid-lines & Chart-Key
plt.grid(True, linestyle="--", linewidth=0.8)
plt.legend()

# --- Shows Chart
plt.show()
